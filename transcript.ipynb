# %%
import pandas as pd
import numpy as np

# %%
 df = pd.read_csv('data_for_ai_bot_master_7.csv')

# %%
df
# Out:
#                                       Bot Transcription  \
# 0                                   i dont have any kid
# 1              then we dont have no get quit calling us
# 2                        do you know hat what is it for
# 3     i dont nowwha the credit cardyouknow all have ...
# 4                                         ol be entered
# ...                                                 ...
# 3475  your scar doesnt even match the voice message ...
# 3476  yeah this is supposed to be a steward loan sca...
# 3477  when i picked up i have a voice message that s...
# 3478  how many scars do you want not some kind f lik...
# 3479  the of solar panel they call you opentelliotat...
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
df.head()
# Out:
#                                    Bot Transcription  \
# 0                                i dont have any kid
# 1           then we dont have no get quit calling us
# 2                     do you know hat what is it for
# 3  i dont nowwha the credit cardyouknow all have ...
# 4                                      ol be entered
#
#                                        Recording URL
# 0  http://192.168.88.254/transcription_wav/transc...
# 1  http://192.168.88.254/transcription_wav/transc...
# 2  http://192.168.88.254/transcription_wav/transc...
# 3  http://192.168.88.254/transcription_wav/transc...
# 4  http://192.168.88.254/transcription_wav/transc...

# %%
#displayinf last five rows of dataset
df.tail()
# Out:
#                                       Bot Transcription  \
# 3475  your scar doesnt even match the voice message ...
# 3476  yeah this is supposed to be a steward loan sca...
# 3477  when i picked up i have a voice message that s...
# 3478  how many scars do you want not some kind f lik...
# 3479  the of solar panel they call you opentelliotat...
#
#                                           Recording URL
# 3475  http://192.168.88.254/transcription_wav/transc...
# 3476  http://192.168.88.254/transcription_wav/transc...
# 3477  http://192.168.88.254/transcription_wav/transc...
# 3478  http://192.168.88.254/transcription_wav/transc...
# 3479  http://192.168.88.254/transcription_wav/transc...

# %%
df.shape
# Out:
# (3480, 2)

# %%
df.describe()
# Out:
#        Bot Transcription                                      Recording URL
# count               3480                                               3480
# unique              3479                                               3480
# top                  a e  http://192.168.88.254/transcription_wav/transc...
# freq                   2                                                  1

# %%
df.value_counts()
# Out:
# Bot Transcription                                                                                                                                                       Recording URL
# a   a                                                                                                                                                                   http://192.168.88.254/transcription_wav/transcription_wav/transcription_csvARI4-1636499209.22080-in_4.wav     1
# please leave a method after the tone                                                                                                                                    http://192.168.88.254/transcription_wav/transcription_wav/transcription_csvARI1-1634940922.57603-in_0.wav     1
# ...

# %%
len(df)
# Out:
# 3480

# %%
len(df['Bot Transcription'])
# Out:
# 3480

# %%
len(df['Recording URL'])
# Out:
# 3480

# %%
df.isnull()
# Out:
#       Bot Transcription  Recording URL
# 0                 False          False
# 1                 False          False
# 2                 False          False
# 3                 False          False
# 4                 False          False
# ...                 ...            ...
# 3475              False          False
# 3476              False          False
# 3477              False          False
# 3478              False          False
# 3479              False          False
#
# [3480 rows x 2 columns]

# %%
df.isna()
# Out:
#       Bot Transcription  Recording URL
# 0                 False          False
# 1                 False          False
# 2                 False          False
# 3                 False          False
# 4                 False          False
# ...                 ...            ...
# 3475              False          False
# 3476              False          False
# 3477              False          False
# 3478              False          False
# 3479              False          False
#
# [3480 rows x 2 columns]

# %%
df.isna().any()
# Out:
# Bot Transcription    False
# Recording URL        False
# dtype: bool

# %%
df.isna().any().sum()
# Out:
# 0

# %%
df['Bot Transcription'].duplicated().any()
# Out:
# True

# %%
df['Recording URL'].duplicated().any()
# Out:
# False

# %%
df['Bot Transcription'].unique()
# Out:
# array(['i dont have any kid', 'then we dont have no get quit calling us',
#        'do you know hat what is it for', ...,
#        'when i picked up i have a voice message that said that it was a student long thing',
#        'how many scars do you want not some kind f like getrerly on student loan it another scar its like a hundred in these scars theres the the student losses the credit card gave u the up car warranties up what else is there up is the medicine one team',
#        'the of solar panel they call you opentelliotat you put solar pins on your roof ah theres one way they try to tricky the is like a face political up a donation like a fund campaign fund that they try to get you to the scar count contributing to how many do you won'],
#       dtype=object)

# %%
 df['Bot Transcription'].duplicated().value_counts()
# Out:
# False    3479
# True        1
# Name: Bot Transcription, dtype: int64

# %%
df.drop_duplicates()
# Out:
#                                       Bot Transcription  \
# 0                                   i dont have any kid
# 1              then we dont have no get quit calling us
# 2                        do you know hat what is it for
# 3     i dont nowwha the credit cardyouknow all have ...
# 4                                         ol be entered
# ...                                                 ...
# 3475  your scar doesnt even match the voice message ...
# 3476  yeah this is supposed to be a steward loan sca...
# 3477  when i picked up i have a voice message that s...
# 3478  how many scars do you want not some kind f lik...
# 3479  the of solar panel they call you opentelliotat...
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
df['Bot Transcription'].duplicated().any()
# Out:
# True

# %%
dup= df['Bot Transcription'].value_counts()

# %%
dup[dup > 1]
# Out:
# a e    2
# Name: Bot Transcription, dtype: int64

# %%
df.duplicated(['Bot Transcription']).value_counts()
# Out:
# False    3479
# True        1
# dtype: int64

# %%
df.drop_duplicates(subset ="Bot Transcription",
                     keep = False, inplace = True)

# %%
df['Bot Transcription'].duplicated().any()
# Out:
# False

# %%
df.duplicated(['Bot Transcription']).value_counts()
# Out:
# False    3478
# dtype: int64

# %%
 df
# Out:
#                                       Bot Transcription  \
# 0                                   i dont have any kid
# 1              then we dont have no get quit calling us
# 2                        do you know hat what is it for
# 3     i dont nowwha the credit cardyouknow all have ...
# 4                                         ol be entered
# ...                                                 ...
# 3475  your scar doesnt even match the voice message ...
# 3476  yeah this is supposed to be a steward loan sca...
# 3477  when i picked up i have a voice message that s...
# 3478  how many scars do you want not some kind f lik...
# 3479  the of solar panel they call you opentelliotat...
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
junk=[]
count=1
for i in df['Bot Transcription'].astype(str):
    if 'after the bee' in i:
        print('\n' + str(count) + ' ' +i)
        junk.append(i)
        count+=1
# Out:
# 1 and phone number after the been we will return
#
# 2 did your name and whole number after the been we
#
# 3 am an phone number after the been we took
#
# 4 aime and phone number after the been we will
#
# 5 please lead your name and phone number after the beef we will return
#
# 6 please lead your name and  phone number after the been
#
# 7 aim and phone number after the been we willed
#
# 8 please meet your name and phone number after the beef we will
#
# 9 please leave your name and phone number after the been we will reach
#
# 10 ame an phone number after the been we will return
#
# 11 give a voicemail after the been
#
# 12 les leave your name and phone number after the been we will re
#
# 13 four seven one four nine if not available please leave a voicemail after the been
#
# 14 topped your name and phone number after the been we will return
#
# 15 anmanphone number after the been we will
#
# 16 the name and phone number after the beepwe
#
# ...

# %%
junk
# Out:
# ['and phone number after the been we will return',
#  'did your name and whole number after the been we',
#  'am an phone number after the been we took',
#  'aime and phone number after the been we will',
#  'please lead your name and phone number after the beef we will return',
#  'please lead your name and  phone number after the been',
#  'aim and phone number after the been we willed',
#  'please meet your name and phone number after the beef we will',
#  'please leave your name and phone number after the been we will reach',
#  'ame an phone number after the been we will return',
#  'give a voicemail after the been',
#  'les leave your name and phone number after the been we will re',
#  'four seven one four nine if not available please leave a voicemail after the been',
#  'topped your name and phone number after the been we will return',
#  'anmanphone number after the been we will',
#  'the name and phone number after the beepwe',
# ...

# %%
# data= pd.DataFrame({'Bot Transcription':junk})

# %%
# new_data3 = pd.merge( new_data2,rem_o_dataframe, on=["Bot Transcription"], how="outer", indicator=True)

# print(new_data3)


# new_data3 = new_data3.loc[new_data3["_merge"] == "left_only"].drop("_merge", axis=1)

# print(new_data3)

# %%
df.shape
# Out:
# (3478, 2)

# %%
df_rmv_after=df

for i in junk:
    df_rmv_after= df_rmv_after[df_rmv_after['Bot Transcription'] != i]

# %%
df_rmv_after.shape
# Out:
# (3428, 2)

# %%
df=df_rmv_after

# %%
# df_rmv_beep

# %%
# df_new =df_rmv_beep
# df_new

# %%
# df_new[df_new['Bot Transcription'].str.contains("press")]

# %%
# df_new[df_new['Bot Transcription'].str.contains("after the bee")]

# %%
junk1=[]
count=1
for i in df['Bot Transcription'].astype(str):
    if 'press' in i:
        print('\n' + str(count) + ' ' +i)
        junk1.append(i)
        count+=1
# Out:
# 1 if you are satisfied with your message press one o
#
# 2 help eliminate telemarketing calls please press one to prove your human press one
#
# 3 un please record your message when youve finished recording you may hang up or oppress one for more nations to leave a
#
# 4 for seven is not not available at the tone please record your message when you have finished recording you may hang up or press one for more actions
#
# 5 a hello can you hear me low i i ont have to call you back at the town please record your message when you have finished recording you may hang up or press one for more actions
#
# 6 with when you have finished recording simply hang up or pressed the poundkey for further option
#
# 7 all an please record your message when youve finished recording you may hang up or oppress one for more option
#
# ...

# %%
df_rmv_pr = df

for i in junk1:
    df_rmv_pr = df_rmv_pr[df_rmv_pr['Bot Transcription'] != i]

# %%
df_rmv_pr.shape
# Out:
# (3314, 2)

# %%
df=df_rmv_pr
df
# Out:
#                                       Bot Transcription  \
# 0                                   i dont have any kid
# 1              then we dont have no get quit calling us
# 2                        do you know hat what is it for
# 3     i dont nowwha the credit cardyouknow all have ...
# 4                                         ol be entered
# ...                                                 ...
# 3475  your scar doesnt even match the voice message ...
# 3476  yeah this is supposed to be a steward loan sca...
# 3477  when i picked up i have a voice message that s...
# 3478  how many scars do you want not some kind f lik...
# 3479  the of solar panel they call you opentelliotat...
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
3428-50
# Out:
# 3378

# %%
junk3=[]
count=1
for i in df['Bot Transcription'].astype(str):
    if 'record your message' in i:
        print('\n' + str(count) + ' ' +i)
        junk3.append(i)
        count+=1
# Out:
# 1 ad the tone please record your message when you finished
#
# 2 add the tone please record your message when you finish
#
# 3 all of our agents are busy helping other customers at the tone please record your message when you finished rico
#
# 4 know please record your message when you have
#
# 5 nothing has been recorded record your message after the tone sadly
#
# 6 cant take your call now at the tone please record your message when you have finished
#
# 7 nothing has been recorded record your message after the tone simply hang up with
#
# 8 onto so you shown not get back to you properly  tenfold at a great day but at the town please record your message when you have
#
# 9 nothing has been recorded record your message after the tone simply had

# %%
junk3
# Out:
# ['ad the tone please record your message when you finished',
#  'add the tone please record your message when you finish',
#  'all of our agents are busy helping other customers at the tone please record your message when you finished rico',
#  'know please record your message when you have',
#  'nothing has been recorded record your message after the tone sadly',
#  'cant take your call now at the tone please record your message when you have finished',
#  'nothing has been recorded record your message after the tone simply hang up with',
#  'onto so you shown not get back to you properly  tenfold at a great day but at the town please record your message when you have',
#  'nothing has been recorded record your message after the tone simply had']

# %%
df_rmv_record=df

for i in junk3:
    df_rmv_record= df_rmv_record[df_rmv_record['Bot Transcription'] != i]
# 3428

# %%
df=df_rmv_record

# %%
df
# Out:
#                                       Bot Transcription  \
# 0                                   i dont have any kid
# 1              then we dont have no get quit calling us
# 2                        do you know hat what is it for
# 3     i dont nowwha the credit cardyouknow all have ...
# 4                                         ol be entered
# ...                                                 ...
# 3475  your scar doesnt even match the voice message ...
# 3476  yeah this is supposed to be a steward loan sca...
# 3477  when i picked up i have a voice message that s...
# 3478  how many scars do you want not some kind f lik...
# 3479  the of solar panel they call you opentelliotat...
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
junk2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-8b078aada9f8> in <module>
# ----> 1 junk2
#
# NameError: name 'junk2' is not defined

# %%
df_rmv_pr=df

for i in junk1:
    df_rmv_pr= df_rmv_pr[df_rmv_pr['Bot Transcription'] != i]
# 3428

# %%
df_rmv_pr.shape
# Out:
# (3314, 2)

# %%
df
# Out:
#                                       Bot Transcription  \
# 0                                   i dont have any kid
# 1              then we dont have no get quit calling us
# 2                        do you know hat what is it for
# 3     i dont nowwha the credit cardyouknow all have ...
# 4                                         ol be entered
# ...                                                 ...
# 3475  your scar doesnt even match the voice message ...
# 3476  yeah this is supposed to be a steward loan sca...
# 3477  when i picked up i have a voice message that s...
# 3478  how many scars do you want not some kind f lik...
# 3479  the of solar panel they call you opentelliotat...
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
# numbers = ["zero",'one', 'two', 'three', 'four', 'five','six','seven','eight','nine','ten']
# junk4=[]
# count=0
# for i in numbers:
#     for j in df['Bot Transcription'].astype(str):
#         if i in j:
#             print('\n' + str(count) + ' ' +j)
#             junk4.append(j)
#             count+=1

# %%
# li = list(set(li))

# %%
junk5=[]
count=1
for i in df['Bot Transcription'].astype(str):
    if 'zero' in i:
        print('\n' + str(count) + ' ' +i)
        junk5.append(i)
        count+=1
# Out:
# 1 three zero eight zero three zero seven three five
#
# 2 hall you reach three zero one four six zero zero two nine five please leave a message will call you back
#
# 3 all right zero nine twenty four
#
# 4 seven zero nine zero is not available
#
# 5 for three two two four seven zero eight nine is not available the mailbox is full and cannot accept any messages at this time good bye
#
# 6 i im sorry four marrow one seven seven zero four four zero one nine six two three three t and
#
# 7 four zero one seven seven zero four four zero one nine six two three three seven
#
# 8 four six zero seven two
#
# 9 si to feel zero one one two see
#
# 10 no no in te one he zero
#
# 11 uhhuh yeah at i dont have a credit card and i have zero din
#
# 12 nine four zero has been disconnected the number four eight zero five one three eight nine four zero has been disconnected no further information is available about this number
#
# ...

# %%
junk5.pop(5)
# Out:
# 'i im sorry four marrow one seven seven zero four four zero one nine six two three three t and'

# %%
junk5
# Out:
# ['three zero eight zero three zero seven three five',
#  'hall you reach three zero one four six zero zero two nine five please leave a message will call you back',
#  'all right zero nine twenty four',
#  'seven zero nine zero is not available',
#  'for three two two four seven zero eight nine is not available the mailbox is full and cannot accept any messages at this time good bye',
#  'four zero one seven seven zero four four zero one nine six two three three seven',
#  'four six zero seven two',
#  'si to feel zero one one two see',
#  'no no in te one he zero',
#  'uhhuh yeah at i dont have a credit card and i have zero din',
#  'nine four zero has been disconnected the number four eight zero five one three eight nine four zero has been disconnected no further information is available about this number',
#  'please leave your message for two two nine six three zero one seven six eight',
#  'zero six one two eight nine',
# ...

# %%
junk5.pop(9)
# Out:
# 'uhhuh yeah at i dont have a credit card and i have zero din'

# %%
junk6=[]
count=0
for i in df['Bot Transcription'].astype(str):
    if 'yeah yeah okay' in i:
        print('\n' + str(count) + ' ' +i)
        junk6.append(i)
        count+=1
# Out:
# 0 yeah yeah okay

# %%
df_rmv_yeah=df

for i in junk6:
    df_rmv_yeah= df_rmv_yeah[df_rmv_yeah['Bot Transcription'] != i]

# %%
df=df_rmv_yeah

# %%
df
# Out:
#                                       Bot Transcription  \
# 0                                   i dont have any kid
# 1              then we dont have no get quit calling us
# 2                        do you know hat what is it for
# 3     i dont nowwha the credit cardyouknow all have ...
# 4                                         ol be entered
# ...                                                 ...
# 3475  your scar doesnt even match the voice message ...
# 3476  yeah this is supposed to be a steward loan sca...
# 3477  when i picked up i have a voice message that s...
# 3478  how many scars do you want not some kind f lik...
# 3479  the of solar panel they call you opentelliotat...
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
junk9=[]
count=0
for i in df['Bot Transcription'].astype(str):
    if 'your name'  in i:
        print('\n' + str(count) + ' ' +i)
        junk9.append(i)
        count+=1
# Out:
# 0 please lead your name and full number for the been we will
#
# 1 your name
#
# 2 invading placed for windows and doors and skylight we can at youcoll right now we med your name message after the done thank you for calling
#
# 3 leave your name and phone number after the bear
#
# 4 take your call at the moment but its very important to him please leave your name and number and hell get back with you as soon as you can thanks for calling and have a great day
#
# 5 cant get to my phone right now but if you will please leave a detailed message name a number i will return your call at my earliest convenience again i cannot answer right now but if you leave your name and number i will give you a call but thank you and be blessed
#
# 6 pleas leave your name and number and i will call you back at my earliest convenience god bless and have a great day
#
# 7 o your call after the be please leave your name and phone number and ill begin your call
#
# ...

# %%
junk9
# Out:
# ['please lead your name and full number for the been we will',
#  'your name',
#  'invading placed for windows and doors and skylight we can at youcoll right now we med your name message after the done thank you for calling',
#  'leave your name and phone number after the bear',
#  'take your call at the moment but its very important to him please leave your name and number and hell get back with you as soon as you can thanks for calling and have a great day',
#  'cant get to my phone right now but if you will please leave a detailed message name a number i will return your call at my earliest convenience again i cannot answer right now but if you leave your name and number i will give you a call but thank you and be blessed',
#  'pleas leave your name and number and i will call you back at my earliest convenience god bless and have a great day',
#  'o your call after the be please leave your name and phone number and ill begin your call',
# ...

# %%
df
# Out:
#                                       Bot Transcription  \
# 0                                   i dont have any kid
# 1              then we dont have no get quit calling us
# 2                        do you know hat what is it for
# 3     i dont nowwha the credit cardyouknow all have ...
# 4                                         ol be entered
# ...                                                 ...
# 3475  your scar doesnt even match the voice message ...
# 3476  yeah this is supposed to be a steward loan sca...
# 3477  when i picked up i have a voice message that s...
# 3478  how many scars do you want not some kind f lik...
# 3479  the of solar panel they call you opentelliotat...
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
junk11=[]
count=0
for i in df['Bot Transcription'].astype(str):
    if 'hang up'  in i:
        print('\n' + str(count) + ' ' +i)
        junk11.append(i)
        count+=1
# Out:
# 0 were sorry due to heavy calling we cannot complete your call at this time will you please hang up and try your call later if you call it
#
# 1 was i aint same hello ho hello are you listening i have never had a credit card dead in my lo are you listing im going to hang up if you dont listen
#
# 2 meeting your call please hang up
#
# 3 t a minute the guy said you should hang up is that your boss
#
# 4 is your boss telling you to hang up you should listen to you loss i hear him hang up
#
# 5 one more time im going to say hello and then im going to hang up so never you are that way
#
# 6 allies taught the number you are calling is not accepting your call please hang up
#
# 7 did you hang up on me
#
# 8 he hang up of
#
# 9 at extension three four eight zero is busy to leave a message begin speaking at the tone when you have finished push star then pound or just hang up
#
# 10 i give mat e treat dont just keep talking theyre all hang up
#
# ...

# %%
df_rmv_hng=df

for i in junk11:
    df_rmv_hng= df_rmv_hng[df_rmv_hng['Bot Transcription'] != i]

# %%
df=df_rmv_hng

# %%
df
# Out:
#                                       Bot Transcription  \
# 0                                   i dont have any kid
# 1              then we dont have no get quit calling us
# 2                        do you know hat what is it for
# 3     i dont nowwha the credit cardyouknow all have ...
# 4                                         ol be entered
# ...                                                 ...
# 3475  your scar doesnt even match the voice message ...
# 3476  yeah this is supposed to be a steward loan sca...
# 3477  when i picked up i have a voice message that s...
# 3478  how many scars do you want not some kind f lik...
# 3479  the of solar panel they call you opentelliotat...
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
df
# Out:
#                                       Bot Transcription  \
# 0                                   i dont have any kid
# 1              then we dont have no get quit calling us
# 2                        do you know hat what is it for
# 3     i dont nowwha the credit cardyouknow all have ...
# 4                                         ol be entered
# ...                                                 ...
# 3475  your scar doesnt even match the voice message ...
# 3476  yeah this is supposed to be a steward loan sca...
# 3477  when i picked up i have a voice message that s...
# 3478  how many scars do you want not some kind f lik...
# 3479  the of solar panel they call you opentelliotat...
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
junk12=[]
count=0
for i in df['Bot Transcription'].astype(str):
    if 'e a o o o'  in i:
        print('\n' + str(count) + ' ' +i)
        junk12.append(i)
        count+=1
# Out:
# 0 e a o o o  hi
#
# 1 he a o o o o o he a he

# %%
df_rmv_ooo=df

for i in junk12:
    df_rmv_ooo= df_rmv_ooo[df_rmv_ooo['Bot Transcription'] != i]

# %%
df=df_rmv_ooo

# %%
df
# Out:
#                                       Bot Transcription  \
# 0                                   i dont have any kid
# 1              then we dont have no get quit calling us
# 2                        do you know hat what is it for
# 3     i dont nowwha the credit cardyouknow all have ...
# 4                                         ol be entered
# ...                                                 ...
# 3475  your scar doesnt even match the voice message ...
# 3476  yeah this is supposed to be a steward loan sca...
# 3477  when i picked up i have a voice message that s...
# 3478  how many scars do you want not some kind f lik...
# 3479  the of solar panel they call you opentelliotat...
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
junk13=[]
count=0
for i in df['Bot Transcription'].astype(str):
    if 'voicemail'  in i:
        print('\n' + str(count) + ' ' +i)
        junk13.append(i)
        count+=1
# Out:
# 0 im sorry that i missed your call please leave me a voicemail and i will get back to you as soon as i can thank you
#
# 1 could please leave me a voicemail or send me a text and ill return to call students i can thank take care
#
# 2 your call has been forwarded to the voicemail for woman english no on
#
# 3 call has been forwarded to the voicemail for polychromic no one is

# %%
df_rmv_voice=df

for i in junk13:
    df_rmv_voice= df_rmv_voice[df_rmv_voice['Bot Transcription'] != i]

# %%
df=df_rmv_voice

# %%
df
# Out:
#                                       Bot Transcription  \
# 0                                   i dont have any kid
# 1              then we dont have no get quit calling us
# 2                        do you know hat what is it for
# 3     i dont nowwha the credit cardyouknow all have ...
# 4                                         ol be entered
# ...                                                 ...
# 3475  your scar doesnt even match the voice message ...
# 3476  yeah this is supposed to be a steward loan sca...
# 3477  when i picked up i have a voice message that s...
# 3478  how many scars do you want not some kind f lik...
# 3479  the of solar panel they call you opentelliotat...
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
junk16=[]
count=0
for i in df['Bot Transcription'].astype(str):
    if 'please'  in i:
        print('\n' + str(count) + ' ' +i)
        junk16.append(i)
        count+=1
# Out:
# 0 y seven seven i right please little match
#
# 1 please lead your name and full number for the been we will
#
# 2 recall please leave up the ridge after the tone
#
# 3 i like to speak to james please
#
# 4 can you please stop calling us
#
# 5 in or away from my phone right now not please
#
# 6 im holding hotel please take me off your calling list
#
# 7 at the tone please record i
#
# 8 take your call at the moment but its very important to him please leave your name and number and hell get back with you as soon as you can thanks for calling and have a great day
#
# 9 sure can i speak to an gait please
#
# 10 i would like to speak to an agent please
#
# 11 please leave the message after the beat
#
# 12 can you take me out your lift please can you take me off your list please do note
#
# 13 ninety four eight three no one is able to come to the phone right now so please leave your message at the tone and will get back to you as soon as possible thank you and have a great day
#
# ...

# %%
# junks.remove('take your call at the moment but its very important to him please leave your name and number and hell get back with you as soon as you can thanks for calling and have a great day
# ', 'please note federal regulations require that you make a phone call send a text message or go online every thirty day of your phone to keep your lifetime service active')

# %%
df_leave=df

for i in junk16:
    df_leave= df_leave[df_leave['Bot Transcription'] != i]

# %%
df=df_leave

# %%
len(df)
# Out:
# 3262

# %%
len('df')
# Out:
# 2

# %%
junk19=[]
count=0
for i in df['Bot Transcription'].astype(str):
    if 'calling'  in i:
        print('\n' + str(count) + ' ' +i)
        junk19.append(i)
        count+=1
# Out:
# 0 then we dont have no get quit calling us
#
# 1 youre calling from where
#
# 2 ah youre a jackets thats what you are what are you doing call on the weekend youre not supposed to be calling after five weekend hat are you calling for
#
# 3 invading placed for windows and doors and skylight we can at youcoll right now we med your name message after the done thank you for calling
#
# 4 i dont know who youre calling
#
# 5 hello which pakistani stammered this calling me l well have to give you some noise
#
# 6 youre not calling me same the not is calling me you can rabble along all you want same
#
# 7 we you keep calling her an dont say anything
#
# 8 can you please stop calling us
#
# 9 im holding hotel please take me off your calling list
#
# 10 i dont want to take advantage of the opportunity but thank you for calling you have an nice day bye bye
#
# 11 oh hi james wherever you calling from
#
# 12 no james a terror right where are you calling from james
#
# ...

# %%
unwanted = [8, 11, 13, 16, 17, 27]
 
for ele in sorted(unwanted, reverse = True):
    del junk19[ele]
# Out:
# 'hellohllo oh sorry com a little loud aureus my bat were te a raptyoryouee ok ah i cant te oh my god you can lo of i o i o by bat  imoor okay im so carry about that shall you think her that wherewereof the thin bark c a animal if  baby to be like mon dad  lucy little ben  mo largesorry about that so i go headed y dear r you can hear me okay rightkyou coat i ri it  right right yep yep thank you cried her ah to will be going think it require by yourself nine yougooheade my find in the background think other youre like screaming right in my ear  sky im sorry tat sky i caught most of what you said but con you just repeat the last party i lacked like the last friend of pole e e ou going t walk around the pain but im still listening st tim he the country a a little bit more excited than he should be im really sorry about that i dont o worry to get them  up somewhere to be im really tired what  we think yeah you know what i was actually meant to call you guns because i had ai gotkinoi now h
# ...

# %%
df_ee=df

for i in junk17:
    df_ee= df_ee[df_ee['Bot Transcription'] != i]

# %%
df=df_ee
df
# Out:
#                                       Bot Transcription  \
# 0                                   i dont have any kid
# 1              then we dont have no get quit calling us
# 2                        do you know hat what is it for
# 3     i dont nowwha the credit cardyouknow all have ...
# 4                                         ol be entered
# ...                                                 ...
# 3475  your scar doesnt even match the voice message ...
# 3476  yeah this is supposed to be a steward loan sca...
# 3477  when i picked up i have a voice message that s...
# 3478  how many scars do you want not some kind f lik...
# 3479  the of solar panel they call you opentelliotat...
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...
