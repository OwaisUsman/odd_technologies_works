# %%
# !pip install pydub
# Out:
# Requirement already satisfied: pydub in c:\users\trainee7\anaconda3\lib\site-packages (0.25.1)

# %%
pip install noisereduce
# Out:
# Collecting noisereduce
#   Downloading noisereduce-2.0.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: librosa in c:\users\trainee7\anaconda3\lib\site-packages (from noisereduce) (0.8.1)
# Requirement already satisfied: numpy in c:\users\trainee7\anaconda3\lib\site-packages (from noisereduce) (1.20.1)
# Requirement already satisfied: joblib in c:\users\trainee7\anaconda3\lib\site-packages (from noisereduce) (1.0.1)
# Requirement already satisfied: scipy in c:\users\trainee7\anaconda3\lib\site-packages (from noisereduce) (1.6.2)
# Requirement already satisfied: matplotlib in c:\users\trainee7\anaconda3\lib\site-packages (from noisereduce) (3.3.4)
# Requirement already satisfied: tqdm in c:\users\trainee7\anaconda3\lib\site-packages (from noisereduce) (4.59.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\trainee7\anaconda3\lib\site-packages (from librosa->noisereduce) (0.24.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\trainee7\anaconda3\lib\site-packages (from librosa->noisereduce) (1.5.2)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\trainee7\anaconda3\lib\site-packages (from librosa->noisereduce) (0.2.2)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\trainee7\anaconda3\lib\site-packages (from librosa->noisereduce) (0.10.3.post1)
# Requirement already satisfied: packaging>=20.0 in c:\users\trainee7\anaconda3\lib\site-packages (from librosa->noisereduce) (20.9)
# Requirement already satisfied: audioread>=2.0.0 in c:\users\trainee7\anaconda3\lib\site-packages (from librosa->noisereduce) (2.1.9)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\trainee7\anaconda3\lib\site-packages (from librosa->noisereduce) (5.0.6)
# Requirement already satisfied: numba>=0.43.0 in c:\users\trainee7\anaconda3\lib\site-packages (from librosa->noisereduce) (0.53.1)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\trainee7\anaconda3\lib\site-packages (from numba>=0.43.0->librosa->noisereduce) (0.36.0)
# Requirement already satisfied: setuptools in c:\users\trainee7\anaconda3\lib\site-packages (from numba>=0.43.0->librosa->noisereduce) (52.0.0.post20210125)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\trainee7\anaconda3\lib\site-packages (from packaging>=20.0->librosa->noisereduce) (2.4.7)
# Requirement already satisfied: appdirs in c:\users\trainee7\anaconda3\lib\site-packages (from pooch>=1.0->librosa->noisereduce) (1.4.4)
# Requirement already satisfied: requests in c:\users\trainee7\anaconda3\lib\site-packages (from pooch>=1.0->librosa->noisereduce) (2.25.1)
# Requirement already satisfied: six>=1.3 in c:\users\trainee7\anaconda3\lib\site-packages (from resampy>=0.2.2->librosa->noisereduce) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\trainee7\anaconda3\lib\site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa->noisereduce) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\trainee7\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa->noisereduce) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\trainee7\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa->noisereduce) (2.20)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\trainee7\anaconda3\lib\site-packages (from matplotlib->noisereduce) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\trainee7\anaconda3\lib\site-packages (from matplotlib->noisereduce) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\trainee7\anaconda3\lib\site-packages (from matplotlib->noisereduce) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\trainee7\anaconda3\lib\site-packages (from matplotlib->noisereduce) (8.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\trainee7\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa->noisereduce) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\trainee7\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa->noisereduce) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\trainee7\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa->noisereduce) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\trainee7\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa->noisereduce) (2.10)
# Installing collected packages: noisereduce
# Successfully installed noisereduce-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from os.path import dirname, join as pjoin
from scipy.io import wavfile
import scipy.io

# %%
import noisereduce as nr
# load data
rate, data = scipy.io.wavfile.read(r"Z:\audios\T_1\ARI8-1635807597.25953-in.wav")
# perform noise reduction
reduced_noise = nr.reduce_noise(y=data, sr=rate)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
reduced_noise
# Out:
# memmap([0, 0, 0, ..., 0, 0, 0], dtype=int16)

# %%
import IPython

# %%
IPython.display.Audio(data=reduced_noise, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# data_dir = pjoin(dirname(scipy.io.__file__), 'tests', 'data')
# wav_fname = pjoin(data_dir, 'ARI5-1635456032.1751-in.wav'
# Out:
#   File "<ipython-input-15-a788dfd5ad94>", line 2
#     wav_fname = pjoin(data_dir, 'ARI5-1635456032.1751-in.wav'
#                                                              ^
# SyntaxError: unexpected EOF while parsing

# %%
# samplerate, data = wavfile.read(wav_fname)
# print(f"number of channels = {data.shape[1]}") 
# number of channels = 2
# length = data.shape[0] / samplerate
# print(f"length = {length}s")
# Out:
#   File "<ipython-input-19-bb6ea2031f9a>", line 3
#     number of channels = 2
#            ^
# SyntaxError: invalid syntax

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# time = np.linspace(0., length, data.shape[0])
# plt.plot(time, data[:, 0], label="Left channel")
# plt.plot(time, data[:, 1], label="Right channel")
# plt.legend()
# plt.xlabel("Time [s]")
# plt.ylabel("Amplitude")
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-35c9c9319730> in <module>
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 time = np.linspace(0., length, data.shape[0])
#       4 plt.plot(time, data[:, 0], label="Left channel")
#       5 plt.plot(time, data[:, 1], label="Right channel")
#
# NameError: name 'length' is not defined

# %%
import IPython.display as ipd
ipd.Audio('reduced_noise ')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-93c5900de409> in <module>
#       1 import IPython.display as ipd
# ----> 2 ipd.Audio('reduced_noise ')
#
# ~\Anaconda3\lib\site-packages\IPython\lib\display.py in __init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     114         if self.data is not None and not isinstance(self.data, bytes):
#     115             if rate is None:
# --> 116                 raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
#     117             self.data = Audio._make_wav(data, rate, normalize)
#     118
#
# ValueError: rate must be specified when data is a numpy array or list of audio samples.
